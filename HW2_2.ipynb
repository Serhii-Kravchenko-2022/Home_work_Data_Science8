# %% [markdown]
# Проведіть аналіз файлу 2017_jun_final.csv. Файл містить результати опитування розробників у червні 2017 року.

# %% [markdown]
# 1. Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv

# %%
import pandas as pd
import numpy as np
from google.colab import drive

drive.mount('/DataScience8')
file = '/DataScience8/MyDrive/DataScience8/2017_jun_final.csv'
df = pd.read_csv(file)
df
# Out:
# Drive already mounted at /DataScience8; to attempt to forcibly remount, call drive.mount("/DataScience8", force_remount=True).
#          N                 Должность Язык.программирования Специализация  \
# 0        1        Junior QA engineer                   NaN     Manual QA
# 1        2        Junior QA engineer                   NaN     Manual QA
# 2        3         Software Engineer               C#/.NET           NaN
# 3        4         Software Engineer            JavaScript           NaN
# 4        5  Senior Software Engineer            JavaScript           NaN
# ...    ...                       ...                   ...           ...
# 8699  8700               QA engineer                   NaN     Manual QA
# 8700  8701                 Marketing                   NaN           NaN
# 8701  8702  Junior Software Engineer            Ruby/Rails           NaN
# 8702  8703                 Team lead                   NaN           NaN
# ...

# %% [markdown]
# 2. Прочитайте отриману таблицю, використовуючи метод head

# %%
df.head()
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# ...

# %% [markdown]
# 3. Визначте розмір таблиці за допомогою методу shape

# %%
df.shape
# Out:
# (8704, 25)

# %% [markdown]
# 4. Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
df.dtypes
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# ...

# %% [markdown]
# 5. Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
for column in df.columns:
    missing = df[column].isnull().sum()
    total = df[column].shape[0]
    missing_ratio = missing / total
    print(f'{column}: {missing_ratio:.2%}')
# Out:
# N: 0.00%
# Должность: 0.00%
# Язык.программирования: 44.23%
# Специализация: 82.94%
# Общий.опыт.работы: 0.00%
# Опыт.работы.на.текущем.месте: 0.00%
# Зарплата.в.месяц: 0.00%
# Изменение.зарплаты.за.12.месяцев: 0.00%
# Город: 0.00%
# Размер.компании: 0.00%
# Тип.компании: 0.00%
# Пол: 0.00%
# Возраст: 0.00%
# Образование: 0.00%
# Университет: 4.11%
# Еще.студент: 0.00%
# Уровень.английского: 0.00%
# Предметная.область: 2.56%
# Дата.заполнения: 0.00%
# User.Agent: 0.00%
# exp: 0.00%
# current_job_exp: 0.00%
# salary: 0.00%
# Валюта: 99.89%
# cls: 18.08%

# %% [markdown]
# 6. Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"

# %%
for column in df.columns:
    if df[column].isnull().sum() != 0 and column != 'Язык.программирования':
       df = df.drop(column, axis=1)
df.head()
# Out:
#    N                 Должность Язык.программирования Общий.опыт.работы  \
# 0  1        Junior QA engineer                   NaN               0.5
# 1  2        Junior QA engineer                   NaN  меньше 3 месяцев
# 2  3         Software Engineer               C#/.NET                 4
# 3  4         Software Engineer            JavaScript                 5
# 4  5  Senior Software Engineer            JavaScript    10 и более лет
#
#   Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0                          0.5               400
# 1             меньше 3 месяцев               430
# 2                            1              2500
# 3                            4              2000
# 4                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  \
# 0                                 0  Харьков       до 10 человек
# 1                               130  Харьков  свыше 1000 человек
# ...

# %% [markdown]
# 7. Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

# %%
for column in df.columns:
    missing = df[column].isnull().sum()
    total = df[column].shape[0]
    missing_ratio = missing / total
    print(f'{column}: {missing_ratio:.2%}')
# Out:
# N: 0.00%
# Должность: 0.00%
# Язык.программирования: 44.23%
# Общий.опыт.работы: 0.00%
# Опыт.работы.на.текущем.месте: 0.00%
# Зарплата.в.месяц: 0.00%
# Изменение.зарплаты.за.12.месяцев: 0.00%
# Город: 0.00%
# Размер.компании: 0.00%
# Тип.компании: 0.00%
# Пол: 0.00%
# Возраст: 0.00%
# Образование: 0.00%
# Еще.студент: 0.00%
# Уровень.английского: 0.00%
# Дата.заполнения: 0.00%
# User.Agent: 0.00%
# exp: 0.00%
# current_job_exp: 0.00%
# salary: 0.00%

# %% [markdown]
# 8. Видаліть усі рядки у вихідній таблиці за допомогою методу dropna

# %%
df.dropna(how='any', inplace=True)

# %% [markdown]
# 9. Визначте новий розмір таблиці за допомогою методу shape

# %%
df.shape
# Out:
# (4854, 20)

# %% [markdown]
# 10. Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python

# %%
python_data = df.loc[df['Язык.программирования'] == 'Python']
python_data
# Out:
#          N                 Должность Язык.программирования Общий.опыт.работы  \
# 12      13         Software Engineer                Python                 1
# 68      69         Software Engineer                Python               1.5
# 87      88  Junior Software Engineer                Python               0.5
# 114    115  Junior Software Engineer                Python               1.5
# 143    144  Junior Software Engineer                Python                 1
# ...    ...                       ...                   ...               ...
# 8546  8547         Software Engineer                Python                 5
# 8625  8626         Software Engineer                Python                 4
# 8635  8636  Senior Software Engineer                Python    10 и более лет
# 8673  8674  Junior Software Engineer                Python               0.5
# 8695  8696         Software Engineer                Python                 1
#
# ...

# %% [markdown]
# 11. Визначте розмір таблиці python_data за допомогою методу shape

# %%
python_data.shape
# Out:
# (207, 20)

# %% [markdown]
# 12. Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

# %%
grouped = python_data.groupby('Должность').mean()
grouped
# Out:
# <ipython-input-40-191032034d3d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped = python_data.groupby('Должность').mean()
#                                     N  Зарплата.в.месяц  \
# Должность
# Junior Software Engineer  3559.063492        560.841270
# Senior Software Engineer  4781.870968       3387.096774
# Software Engineer         3668.840000       1799.070000
# System Architect          6989.000000       4000.000000
# Technical Lead            5370.181818       3165.909091
#
#                           Изменение.зарплаты.за.12.месяцев    Возраст  \
# Должность
# Junior Software Engineer                        181.031746  24.174603
# Senior Software Engineer                        431.612903  29.064516
# Software Engineer                               479.830000  26.630000
# ...

# %% [markdown]
# 13. Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"

# %%
salary_agg = python_data.groupby('Должность').agg({'Зарплата.в.месяц': ['min', 'max']})
salary_agg
# Out:
#                          Зарплата.в.месяц
#                                       min   max
# Должность
# Junior Software Engineer              100  1250
# Senior Software Engineer             1300  9200
# Software Engineer                     500  5400
# System Architect                     3000  5000
# Technical Lead                       1425  6200

# %% [markdown]
# 14. Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"

# %%
from numpy.core.fromnumeric import mean
def fill_avg_salary(*args):
    avg_salary = mean(*args)
    return avg_salary

salary_agg['avg'] = salary_agg.apply(fill_avg_salary, axis=1)
salary_agg
# Out:
#                          Зарплата.в.месяц           avg
#                                       min   max
# Должность
# Junior Software Engineer              100  1250   675.0
# Senior Software Engineer             1300  9200  5250.0
# Software Engineer                     500  5400  2950.0
# System Architect                     3000  5000  4000.0
# Technical Lead                       1425  6200  3812.5

# %% [markdown]
# 15. Створіть описову статистику за допомогою методу describe для нового стовпчика.

# %%
salary_agg['avg'].describe()
# Out:
# count       5.000000
# mean     3337.500000
# std      1700.091909
# min       675.000000
# 25%      2950.000000
# 50%      3812.500000
# 75%      4000.000000
# max      5250.000000
# Name: avg, dtype: float64

# %% [markdown]
# 16. Збережіть отриману таблицю в CSV файл

# %%
salary_agg.to_csv('/DataScience8/MyDrive/DataScience8/salary_agg.csv', index=False)

# %%
import seaborn as sns

sns.scatterplot(data=python_data, x='Возраст', y='salary')
# Out:
# <Axes: xlabel='Возраст', ylabel='salary'>

# %%
sns.relplot(data=python_data, x='Возраст', y='salary', kind='scatter', col='Должность')

# %%
python_data.columns
# Out:
# Index(['N', 'Должность', 'Язык.программирования', 'Общий.опыт.работы',
#        'Опыт.работы.на.текущем.месте', 'Зарплата.в.месяц',
#        'Изменение.зарплаты.за.12.месяцев', 'Город', 'Размер.компании',
#        'Тип.компании', 'Пол', 'Возраст', 'Образование', 'Еще.студент',
#        'Уровень.английского', 'Дата.заполнения', 'User.Agent', 'exp',
#        'current_job_exp', 'salary'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

sns.relplot(data=python_data, x='Возраст', y='Должность', kind='scatter', col='Пол', hue='Зарплата.в.месяц', size='salary')
